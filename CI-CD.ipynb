# %% [markdown]
# # CI/CD Pipeline

# %% [markdown]
# This notebook defines a basic CI/CD pipeline, which achieves automated building of the required chatbot components, as well as deployment of the final chatbot. **Simply run the cells in this notebook from top to bottom to accomplish this.**

# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Building Components

# %% [markdown]
# ### Named Entity Recognition

# %%
# %run 'drive/MyDrive/COM3029_coursework_2/Main/Components/ner-fixed.ipynb'

# %% [markdown]
# ### Intent Classifier

# %%
# %run 'drive/MyDrive/COM3029_coursework_2/Main/Components/intent_classifier.ipynb'

# %% [markdown]
# ## Deployment

# %%
# Interrupt execution to close endpoint
# %run 'drive/MyDrive/COM3029_coursework_2/Main/COM3029 coursework 2.ipynb'
